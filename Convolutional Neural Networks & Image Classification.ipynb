# %% [markdown]
# <center><h1>Image Classification with Convolutional Neural Networks</h1></center>
#
# ### Vocabulary
#
# ***Filter:***
#
# ***Stride***
#
# ***Padding***
#
#     ***SAME***
#
#     ***VALID***
